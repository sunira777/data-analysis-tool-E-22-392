# %%
# !pip install git+https://github.com/sunira777/data-analysis-tool-E-22-392.git
# Out:
# ...
#   Cloning https://github.com/sunira777/data-analysis-tool-E-22-392.git to /tmp/pip-req-build-93i1a0f5
#   Running command git clone --filter=blob:none --quiet https://github.com/sunira777/data-analysis-tool-E-22-392.git /tmp/pip-req-build-93i1a0f5
#   Resolved https://github.com/sunira777/data-analysis-tool-E-22-392.git to commit 8e554015711d3c741e0a02221039993c24a6ae44
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ### Set up environment

# %%
# Import the custom tool you just built!
from data_analysis.core import DataInspector

# Initialize it
inspector = DataInspector()

# This will prompt you to upload your titanic.csv file
inspector.upload_data()
# Out:
# Please upload your CSV file...
#      <input type="file" id="files-359c6fc4-adc8-4af7-bd1e-544cb4d462ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-359c6fc4-adc8-4af7-bd1e-544cb4d462ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Clean the dataset
inspector.remove_duplicates()
inspector.handle_missing_values(strategy='median')
# Out:
# Removed 0 duplicate rows.
# Missing values handled using 'median' strategy.

# %% [markdown]
# ### Initial Inspection & Removing Useless Columns

# %%
# View structural breakdown before cleaning
print("--- RAW DATA PREVIEW ---")
inspector.summary()

# Targeted Deletion: Drop highly unique/messy string columns
inspector.delete_columns(['PassengerId', 'Name', 'Ticket', 'Cabin'])
# Out:
# --- RAW DATA PREVIEW ---
# Dimensions: 891 Rows, 12 Columns
#
# Data Types Breakdown:
# int64      5
# object     4
# float64    3
# Name: count, dtype: int64
#
# First 5 Rows Preview:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch    Ticket     Fare    Cabin Embarked
# 0      0  236171.0   7.2500  B96 B98        S
# ...

# %% [markdown]
# ### Data Cleaning (Nulls & Outliers)

# %%
# Remove exact duplicate rows
inspector.remove_duplicates()

# Impute missing values (Age and Embarked) using the median/mode strategy
inspector.handle_missing_values(strategy='median')

# Remove extreme outliers in ticket Fare using your custom IQR logic
inspector.handle_outliers(target_columns=['Fare'], action='drop')

print("\n--- DATA AFTER CLEANING ---")
inspector.summary()
# Out:
# Removed 116 duplicate rows.
# Missing values handled using 'median' strategy.
# Handled outliers in ['Fare']. Removed 102 rows.
#
# --- DATA AFTER CLEANING ---
# Dimensions: 673 Rows, 8 Columns
#
# Data Types Breakdown:
# int64      4
# object     2
# float64    2
# Name: count, dtype: int64
#
# First 5 Rows Preview:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# 1. See the distribution of Age and Fare (Generates 3-panel subplots)
inspector.plot_numerical(['Age', 'Fare'])

# 2. See the breakdown of Male vs Female (Generates Bar Chart with percentages)
inspector.plot_categorical_frequency('Sex')

# 3. Box plot showing relationship between Passenger Class and Fare
inspector.plot_relationship('Pclass', 'Fare')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Advanced Statistical Heatmap

# %%
# Generate the unified heatmap
inspector.plot_all_associations_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Machine Learning Preparation

# %%
# Standardize numeric columns, One-Hot encode categories, and leave 'Survived' alone as our target!
final_ml_df = inspector.create_normalized_data_df(
    num_method='standard',
    cat_method='onehot',
    preserve_cols=['Survived']
)

print("\nFinal Machine Learning Ready Dataset Preview:")
display(final_ml_df.head())
# Out:
# Final Machine Learning Ready Dataset Preview:
#    Survived    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0         0  0.750760 -0.511238  0.480043 -0.474198 -0.827523       1.0
# 1         1 -1.873975  0.665675  0.480043 -0.474198  3.499492       0.0
# 2         1  0.750760 -0.217010 -0.498954 -0.474198 -0.781910       0.0
# 3         1 -1.873975  0.445004  0.480043 -0.474198  2.270766       0.0
# 4         0  0.750760  0.445004 -0.498954 -0.474198 -0.773463       1.0
#
#    Embarked_Q  Embarked_S
# 0         0.0         1.0
# 1         0.0         0.0
# 2         0.0         1.0
# 3         0.0         1.0
# 4         0.0         1.0
